# %% [markdown]
# <a href="https://colab.research.google.com/github/lack-of-sleep/2609Study/blob/main/06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits
#sklearn 라이브러리 datasets에서 이미지를 숫자화 시킨 데이터(digits) load
import matplotlib.pyplot as plt
#matplolib는 그래프 시각화 라이브러리의 pyplot 모듈을 가져옴 이 명령어를 plt라고 별칭
digit=load_digits()
#digit에 로드한 숫자데이터셋 저장
digit.images[0]
#digit에 있는 이미지 배열에서 첫번째 이미지 데이터를 가져옴(출력x)
plt.matshow(digit.images[0])
#행렬 형태 시각화, 값 크기에 따라 색상이 다름
plt.show()
#그래프 출력

# %%
dir(digit)
#digit가 가지고 있는 요소들 출력
# Out:
# numpy.ndarray

# %%
type(digit.images)
# Out:
# numpy.ndarray

# %%
type(digit.data)
# Out:
# numpy.ndarray

# %%
digit.data.shape
#64개의 픽셀이 있음(1차원)
# Out:
# (1797, 64)

# %%
digit.images.shape
#8x8의 픽셀이 있음(2차원)
# Out:
# (1797, 8, 8)

# %%
a = digit.data.reshape(1797,8,8)
b = digit.images

import numpy as np
np.allclose(a,b)
#allclose = 두 배열의 요소가 같은지 비교
# Out:
# True

# %%
plt.matshow(digit.data.reshape(1797,8,8)[0])
#digit.data.reshape(1797,8,8) = digit.images 라서 결과값이 같음
plt.show()

# %%
plt.matshow(digit.images[8])
plt.show()

# %%
plt.matshow(digit.images[1796])
#마지막 인덱스 요소 출력
plt.show()
#6인지 8인지 모르겠다

# %%
digit.target[1796]
#마지막 요소는 8
# Out:
# np.int64(8)

# %%
digit.target[-1]
#1796 배열이 마지막인지 확인차 다시 마지막(-1)요소를 확인
# Out:
# np.int64(8)
